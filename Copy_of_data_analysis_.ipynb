# %% [markdown]
# <a href="https://colab.research.google.com/github/favas8606/data_analyisis/blob/main/Copy_of_data_analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
sales = pd.read_csv('sales.csv')

# %%
sales.head(10)
#  showing only first 10 data
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# ...

# %%
sales['Category']
# showing only category
# Out:
# 0      Groceries
# 1        Fashion
# 2       Clothing
# 3       Sporting
# 4          Books
#          ...
# 995    Groceries
# 996    Groceries
# 997     Clothing
# 998     Clothing
# 999     Clothing
# Name: Category, Length: 1000, dtype: object

# %%
sales['Category'].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
sales[100:200]
# slicing
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 100   515862366  2/12/2018  10:57  Female    Park lane   Dallas     No
# 101    42787009  3/28/2018  11:25  Female    Park lane   Dallas    Yes
# 102   780195692  2/20/2018  12:42  Female    Park lane   Dallas     No
# 103   881639873  2/27/2018  15:05    Male    Park lane   Dallas    Yes
# 104   443388850   2/5/2018  16:31    Male   Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...          ...      ...    ...
# 195   343603860   2/4/2018  14:57  Female    Park lane   Dallas     No
# 196   925499362  1/12/2018  11:22  Female   Brookfield  NewYork    Yes
# 197   579316236   3/1/2018  13:44  Female  Water tower  Chicago    Yes
# 198   445531158   2/9/2018  20:19  Female    Park lane   Dallas     No
# 199   805526095  3/27/2018  18:00    Male    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 100   Sporting     94         6    564    Card       3
# ...

# %%
sales.iloc[200]
# find 200th data
# Out:
# Invoice ID      576523018
# Date            2/15/2018
# Time                12:35
# Gender               Male
# Location      Water tower
# City              Chicago
# Member                 No
# Category        Groceries
# Price                  82
# Quantity                1
# Total                  82
# Payment              Card
# Rating                  4
# Name: 200, dtype: object

# %%
sales.tail(20)
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 980    34442223  1/10/2018  17:24    Male   Brookfield  NewYork     No
# 981   418253101  3/14/2018  12:25  Female   Brookfield  NewYork     No
# 982   741817151  2/10/2018  14:43  Female   Brookfield  NewYork     No
# 983   169440268  2/17/2018  14:42  Female   Brookfield  NewYork     No
# 984   979059991  3/26/2018  13:48  Female   Brookfield  NewYork    Yes
# 985   266635768  1/29/2018  14:30    Male  Water tower  Chicago    Yes
# 986   321374195  3/17/2018  14:16  Female  Water tower  Chicago     No
# 987   245049016  1/20/2018  10:03  Female    Park lane   Dallas     No
# 988      737210  1/20/2018  20:47  Female  Water tower  Chicago    Yes
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 990   752407865  1/15/2018  10:01    Male  Water tower  Chicago    Yes
# 991   699906043  2/15/2018  12:58    Male   Brookfield  NewYork    Yes
# ...

# %%
sales[sales['Gender'] == 'Male']
# print details of males
# Out:
#      Invoice ID       Date   Time Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 5     263634050   3/9/2018  17:55   Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
# ..          ...        ...    ...    ...          ...      ...    ...
# 992   927909627   3/2/2018  13:35   Male   Brookfield  NewYork     No
# 994   446582560  1/31/2018  19:00   Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19   Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17   Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44   Male   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales[sales['Gender'] == 'Female'].head(10)
# print details of 10 femails
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 1    471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 3    487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4    197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 9    562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10   388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# 13   942406749  1/18/2018  15:20  Female  Water tower  Chicago    Yes
# 14   547572603  3/21/2018  13:23  Female   Brookfield  NewYork     No
# 15   355981315  2/15/2018  15:47  Female   Brookfield  NewYork    Yes
# 16   397754805   2/9/2018  15:59  Female   Brookfield  NewYork    Yes
# 18   542144906   2/6/2018  10:58  Female   Brookfield  NewYork    Yes
#
#      Category  Price  Quantity  Total Payment  Rating
# 1     Fashion     35         5    175    Card       3
# 3    Sporting     89         4    356    Gpay       1
# ...

# %%
sales[sales['Total'] > 100].head()
# print sales greaterthan 100
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
#
#    Category  Price  Quantity  Total Payment  Rating
# 1   Fashion     35         5    175    Card       3
# 2  Clothing     57         2    114    Cash       5
# 3  Sporting     89         4    356    Gpay       1
# 4     Books     82         5    410    Cash       4
# 5  Clothing     52         4    208    Gpay       3

# %%
sales[sales['Payment'] == 'Cash'].head(10)
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 0    460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 2    411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 4    197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 6     99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7    188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 9    562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 12   149894432  1/12/2018  11:12    Male    Park lane   Dallas     No
# 17    90524319  3/19/2018  18:18    Male    Park lane   Dallas    Yes
# 19   729486362   3/7/2018  12:50    Male  Water tower  Chicago     No
# 20   619639105  3/26/2018  19:48  Female   Brookfield  NewYork     No
#
#      Category  Price  Quantity  Total Payment  Rating
# 0   Groceries     30         1     30    Cash       2
# 2    Clothing     57         2    114    Cash       5
# ...

# %%
sales['Payment'].unique()
# Out:
# array(['Cash', 'Card', 'Gpay'], dtype=object)

# %%
sales[sales['City'] == 'NewYork']
# Out:
#      Invoice ID       Date   Time  Gender    Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male  Brookfield  NewYork    Yes
# 5     263634050   3/9/2018  17:55    Male  Brookfield  NewYork    Yes
# 10    388412668  2/26/2018  11:32  Female  Brookfield  NewYork     No
# 14    547572603  3/21/2018  13:23  Female  Brookfield  NewYork     No
# 15    355981315  2/15/2018  15:47  Female  Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...         ...      ...    ...
# 991   699906043  2/15/2018  12:58    Male  Brookfield  NewYork    Yes
# 992   927909627   3/2/2018  13:35    Male  Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female  Brookfield  NewYork    Yes
# 997    82324424   2/6/2018  11:44    Male  Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female  Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales.sum()['Total']
# total sales
# Out:
# 207788

# %%
sales.sum()['Quantity']
# Out:
# 4059

# %%
sales.max()
# maximum of all column
# Out:
# Invoice ID      999665753
# Date             3/9/2018
# Time                20:59
# Gender               Male
# Location      Water tower
# City              NewYork
# Member                Yes
# Category         Sporting
# Price                 100
# Quantity                7
# Total                 693
# Payment              Gpay
# Rating                  5
# dtype: object

# %%
sales.sum()['Total'] - sales.max()['Total']
# difference between total sum and max of total
# Out:
# 207095

# %%
sales[sales['Total'] == sales.max()['Total']]
# print maximum total  == total of rows
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 47    315624039  3/30/2018  19:45  Female  Water tower  Chicago    Yes
# 679   270918350  3/27/2018  13:21  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 47   Groceries     99         7    693    Gpay       3
# 679  Groceries     99         7    693    Gpay       2

# %%
sales['Total'].min()
# minimum of total
# Out:
# 1

# %%
sales[sales['Total'] == sales.min()['Total']]
# Out:
#      Invoice ID       Date   Time  Gender   Location    City Member  \
# 184   801334050  1/21/2018  20:18  Female  Park lane  Dallas     No
# 587   646176653  3/10/2018  19:39    Male  Park lane  Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 184  Furniture      1         1      1    Gpay       2
# 587   Sporting      1         1      1    Cash       2

# %%
sales['Total'].mean()
# mean of total
# Out:
# 207.788

# %%
sales.groupby('City').sum()['Total']
#  sum which is grouped by cities
# Out:
# <ipython-input-125-abfab8d4f4d8>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('City').sum()['Total']
# City
# Chicago    65215
# Dallas     70432
# NewYork    72141
# Name: Total, dtype: int64

# %%
sales.groupby('City').sum()['Total']
# sum of total which grouped by city
# Out:
# <ipython-input-126-75a822415b84>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('City').sum()['Total']
# City
# Chicago    65215
# Dallas     70432
# NewYork    72141
# Name: Total, dtype: int64

# %%
sales.groupby('Gender').sum()['Total']
# Out:
# <ipython-input-127-2c92b81ae3f3>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('Gender').sum()['Total']
# Gender
# Female    106452
# Male      101336
# Name: Total, dtype: int64

# %%
sales.groupby("Category").sum()['Total']
# Out:
# <ipython-input-128-70e042aac6f6>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby("Category").sum()['Total']
# Category
# Books        36103
# Clothing     35925
# Fashion      32778
# Furniture    34141
# Groceries    31236
# Sporting     37605
# Name: Total, dtype: int64

# %%
sales.groupby(['Gender', 'Payment']).sum()['Total']
# Out:
# <ipython-input-129-20ca2575d242>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby(['Gender', 'Payment']).sum()['Total']
# Gender  Payment
# Female  Card       31137
#         Cash       35298
#         Gpay       40017
# Male    Card       33127
#         Cash       37345
#         Gpay       30864
# Name: Total, dtype: int64

# %%
# which location has highest and lowest sales?
# represent bar chart also show the market share for each location using pie chart

# %%
location_list = sales.groupby('Location')

# %%
location_list

# %% [markdown]
# # New Section

# %%
location = [x for x,y in location_list]

# %%
location
# Out:
# ['Brookfield', 'Park lane', 'Water tower']

# %%
a = sales['Location'].unique()

# %%
a
# Out:
# array(['Brookfield', 'Water tower', 'Park lane'], dtype=object)

# %%
shot = sales.groupby('Location').sum()['Total']
# Out:
# <ipython-input-137-86c21c60cb7b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   shot = sales.groupby('Location').sum()['Total']

# %% [markdown]
# # New Section

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(a, shot)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie( shot, labels = a, autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7a49dceb6b90>,
# ...
#  [Text(0.5080357843151303, 0.9756534435214743, 'Brookfield'),
#   Text(-1.0939745592878725, -0.11497679605427102, 'Water tower'),
#   Text(0.6072323961649049, -0.917207074246502, 'Park lane')],
#  [Text(0.27711042780825285, 0.5321746055571678, '34.72%'),
#   Text(-0.596713395975203, -0.06271461602960236, '33.90%'),
#   Text(0.3312176706354026, -0.5002947677708193, '31.39%')])

# %%
# which location had highest male customer and female customer
location_sales = sales.groupby([ 'Gender' , 'Location']).count()['Invoice ID']

# %%
location_sales
# Out:
# Gender  Location
# Female  Brookfield     179
#         Park lane      179
#         Water tower    143
# Male    Brookfield     161
#         Park lane      153
#         Water tower    185
# Name: Invoice ID, dtype: int64

# %%
total = location_sales.unstack(level=0)

# %%
total.plot(kind='bar')
# Out:
# <Axes: xlabel='Location'>

# %%
# what is the month make most sales
pd.to_datetime(sales['Date']).dt.month
# Out:
# 0      1
# 1      3
# 2      2
# 3      1
# 4      2
#       ..
# 995    3
# 996    2
# 997    2
# 998    1
# 999    1
# Name: Date, Length: 1000, dtype: int64

# %%
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# ...

# %%
days = pd.to_datetime(sales['Date']).dt.day

# %%
days
# Out:
# 0      25
# 1      19
# 2      25
# 3      22
# 4      18
#        ..
# 995    26
# 996    20
# 997     6
# 998    29
# 999    31
# Name: Date, Length: 1000, dtype: int64

# %%
sales['days'] = pd.to_datetime(sales['Date']).dt.day

# %%
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  days
# 0  Groceries     30         1     30    Cash       2    25
# 1    Fashion     35         5    175    Card       3    19
# ...

# %%
day_sales = sales.groupby('days').sum()['Total']
# Out:
# <ipython-input-151-deb1f531919d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   day_sales = sales.groupby('days').sum()['Total']

# %%
day_sales
# Out:
# days
# 1     6301
# 2     8247
# 3     8533
# 4     6593
# 5     9177
# 6     5976
# 7     6164
# 8     8313
# 9     9142
# 10    6444
# 11    4755
# 12    7714
# 13    5688
# 14    7978
# 15    9677
# 16    5912
# 17    5833
# 18    4625
# 19    7481
# 20    7333
# 21    4300
# 22    5788
# 23    6949
# 24    7819
# 25    8638
# 26    7165
# 27    8154
# 28    6467
# 29    4662
# 30    3530
# 31    2430
# Name: Total, dtype: int64

# %%
day_sales.plot()
# Out:
# <Axes: xlabel='days'>

# %%
day_sales.plot(kind='bar')
# Out:
# <Axes: xlabel='days'>

# %%
day_sales.plot(kind='pie', labels=days, autopct="%1.1f%%")
# Out:
# <Axes: ylabel='Total'>

# %%
# which branch has more members us which has less members?
# which has highest rating and which has lowest rating?

# %%
sales.head(5)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  days
# 0  Groceries     30         1     30    Cash       2    25
# 1    Fashion     35         5    175    Card       3    19
# 2   Clothing     57         2    114    Cash       5    25
# 3   Sporting     89         4    356    Gpay       1    22
# 4      Books     82         5    410    Cash       4    18

# %%
# 1
members = sales.groupby(['Member', 'Location']).count()['Invoice ID']

# %%
members
# Out:
# Member  Location
# No      Brookfield     173
#         Park lane      167
#         Water tower    159
# Yes     Brookfield     167
#         Park lane      165
#         Water tower    169
# Name: Invoice ID, dtype: int64

# %%
bar_members = members.unstack(level=0)

# %%
bar_members.plot(kind="bar")
# Out:
# <Axes: xlabel='Location'>

# %%
# 2
rating = sales.groupby(['Location']).mean()['Rating']
# Out:
# <ipython-input-162-575185d15305>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   rating = sales.groupby(['Location']).mean()['Rating']

# %%
rating.plot(kind="bar")
# Out:
# <Axes: xlabel='Location'>

# %%
plt.pie(rating, labels=location, autopct="%1.4f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7a49dd335f00>,
# ...
#  [Text(0.6130189399201272, 0.913349757376222, 'Brookfield'),
#   Text(-1.092285745140789, 0.13004557263602462, 'Park lane'),
#   Text(0.5007407802097859, -0.9794175161977119, 'Water tower')],
#  [Text(0.33437396722916024, 0.49819077675066653, '31.1841%'),
#   Text(-0.5957922246222485, 0.07093394871055887, '33.8598%'),
#   Text(0.27313133465988315, -0.5342277361078428, '34.9561%')])

# %%
# which city has more female shipping?
# who spends more men or female?
# which type of customer spent more member or men member?
# which product line selles more?
# which product line is popular among women or men?

# %%
# 1
shipping = sales.groupby([ 'Gender', 'City']).count()['Invoice ID']

# %%
shipping.unstack(level=0).plot(kind="bar")
# Out:
# <Axes: xlabel='City'>

# %%
# 2
spend = sales.groupby('Gender').sum()['Total']
# Out:
# <ipython-input-168-f90d9bb6a344>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   spend = sales.groupby('Gender').sum()['Total']

# %%
spend.plot(kind="pie", autopct='%1.2f%%')
# Out:
# <Axes: ylabel='Total'>

# %%
# 3
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  days
# 0  Groceries     30         1     30    Cash       2    25
# 1    Fashion     35         5    175    Card       3    19
# ...

# %%
member = sales.groupby('Member').sum()['Total']
# Out:
# <ipython-input-171-30cd3c5d10ee>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   member = sales.groupby('Member').sum()['Total']

# %%
member.plot(kind="pie", autopct='%1.2f%%')
# Out:
# <Axes: ylabel='Total'>

# %%
# 4
more_sells = sales.groupby('Category').count()['Rating']

# %%
more_sells
# Out:
# Category
# Books        165
# Clothing     170
# Fashion      153
# Furniture    160
# Groceries    174
# Sporting     178
# Name: Rating, dtype: int64

# %%
sell = more_sells.plot(kind="bar")

# %%
# 5
popular = sales.groupby(['Gender','Category']).count()['Quantity']

# %%
popular
# Out:
# Gender  Category
# Female  Books        88
#         Clothing     81
#         Fashion      81
#         Furniture    78
#         Groceries    87
#         Sporting     86
# Male    Books        77
#         Clothing     89
#         Fashion      72
#         Furniture    82
#         Groceries    87
#         Sporting     92
# Name: Quantity, dtype: int64

# %%
popular.unstack(level=0).plot(kind="bar")
# Out:
# <Axes: xlabel='Category'>

# %%
sales['Month'] = pd.to_datetime(sales['Date']).dt.month

# %%
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating  days  Month
# ...

# %%
month_total = sales.groupby('Month').sum()['Total']
# Out:
# <ipython-input-185-b7eb3dc66360>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   month_total = sales.groupby('Month').sum()['Total']

# %%
month_total.plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>
